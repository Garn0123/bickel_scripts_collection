# %%
# Import modules for our exercise
import numpy as np     # numerical package
import pandas as pd    # data organization package
import matplotlib.pyplot as plt # plotting package
import os              # operational system interface package
# %matplotlib inline

# %%
# Import modules for dealing with chemical information
from rdkit import Chem as Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import AllChem as Chem2
from rdkit.Chem import Descriptors as Desc
from rdkit.Chem import Draw
from rdkit.Chem import rdmolfiles as RDFile

import pickle

import math
from collections import defaultdict

import os.path as op

# %%
# Function that reads multi-molecule MOL2 files. Adapted from:
# https://chem-workflows.com/articles/2019/07/18/building-a-multi-molecule-mol2-reader-for-rdkit/
# further adapted from function written by Guilherme Duarte, Rizzo Lab
def mol2_mol_supplier_loop(file):
    ''' This function extracts all the molecules in the multi-molecule
        MOL2 file `file` and returns a list of rdkit.Chem.rdchem.mol 
        object.
        
        Variable         I/O          dtype           default value?
        ------------------------------------------------------------
        file              I           string                  None
        mols              O           list                    N/A
        mols[i]           O           rdkit.Chem.rdchem.mol   N/A
        
    '''
    mols=[]
    
    recording=False
    with open(file, 'r') as f:
        for line in f:
            
            # Determines if @<TRIPOS>MOLECULE is in line, which marks the start
            # of each molecule. Sets the recording variable to True, which is
            # the boolean to write each molecule.
            if ("@<TRIPOS>MOLECULE") in line:
                recording=True
                mol = []
            # Determines if "ROOT" is in line, which marks the end of each
            # molecule. Records the line and sets the recording variable
            # to false.
            elif ("ROOT") in line:
                mol.append(line)
                recording=False
                
                # Makes final adjustments to the data. It must look
                # like the MOL2 file of a single molecule.
                block = ",".join(mol).replace(',','')
                
                # Converts the data of a single molecule to a 
                # rdkit.Chem.rdchem.mol object.
                m=Chem.MolFromMol2Block(block,
                                        sanitize=False,
                                        cleanupSubstructures=False)
                mols.append(m)
                continue
                
            if recording==True:
                mol.append(line)
                
        return(mols)

# %% [markdown]
# # Don't use this unless you need to break things up

# %%
#### A breakup step if you need to truncate the # of molecules you're working with
#### for them to be workable with the amount of available memory.
filename="./2020.01.03_roulette_fixes_combined_molecules.mol2"
o_filename="test_out.mol2"

molecule_counter=0
with open(filename,'r') as f:
    with open(o_filename,'w') as o:
        for line in f:
            if "Name" in line:
                molecule_counter+=1
            if molecule_counter > 100:
                break
            if "###" in line:
                continue
            o.write(line)

# %% [markdown]
# # Actual Code

# %%
filename="./2020.01.03_roulette_fixes_combined_molecules.mol2"

molecule_list=mol2_mol_supplier_loop(filename)
# Out:
# RDKit WARNING: [12:04:46] 1AJV_23_layer379_222: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:04:47] 1AJV_24_layer534_256: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:04:55] 1BJI_24_layer183_94: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:04:55] 1BJI_24_layer571_283: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:04:55] 1BJI_24_layer782_385: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:02] 1C1B_23_layer279_160: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:02] 1C1B_24_layer533_268: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:02] 1C1B_24_layer901_386: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:08] 1C1C_23_layer410_244: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:08] 1C1C_23_layer461_264: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:08] 1C1C_23_layer671_341: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:08] 1C1C_24_layer181_78: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:08] 1C1C_24_layer727_277: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:14] 1DF8_23_layer192_110: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:14] 1DF8_23_layer387_202: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:14] 1DF8_24_layer225_102: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:14] 1DF8_24_layer229_105: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:14] 1DF8_24_layer540_253: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:23] 1DMP_23_layer1498_798: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:32] 1EQH_23_layer226_69: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:37] 1EVE_24_layer277_145: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:43] 1F8B_13_layer1525_478: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:46] 1F8B_24_layer793_443: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:05:55] 1F8C_23_layer522_263: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:04] 1F8D_23_layer89_53: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:04] 1F8D_23_layer176_110: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:04] 1F8D_24_layer130_70: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:12] 1F8E_23_layer303_169: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:12] 1F8E_24_layer777_369: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:20] 1H22_23_layer85_50: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:20] 1H22_23_layer128_71: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:20] 1H22_24_layer343_178: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:20] 1H22_24_layer808_408: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:25] 1HT5_23_layer249_92: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:25] 1HT5_24_layer154_74: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:25] 1HT5_24_layer490_203: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:25] 1HT5_24_layer650_260: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:28] 1HT8_23_layer455_152: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:33] 1HVR_23_layer535_321: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:45] 1J07_24_layer485_218: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:54] 1MER_23_layer934_561: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:06:54] 1MER_23_layer1303_736: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:03] 1MES_23_layer1246_711: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:04] 1MES_24_layer494_252: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:13] 1MET_23_layer845_486: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:13] 1MET_23_layer1168_633: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:23] 1MWE_23_layer152_88: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:23] 1MWE_23_layer269_147: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:23] 1MWE_23_layer293_160: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:39] 1NNC_23_layer136_82: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:39] 1NNC_23_layer174_100: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:40] 1NNC_24_layer916_454: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:46] 1Q4G_24_layer311_130: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:46] 1Q4G_24_layer378_158: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:46] 1Q4G_24_layer611_245: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:50] 1Q84_23_layer706_382: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:50] 1Q84_24_layer322_174: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:07:58] 1QBS_23_layer694_407: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:15] 1SRI_23_layer295_171: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:23] 1SRJ_23_layer90_53: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:30] 1VRU_24_layer284_161: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:30] 1VRU_24_layer480_261: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:45] 1XOG_23_layer427_225: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:45] 1XOG_24_layer533_308: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:54] 1ZGC_23_layer311_166: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:08:54] 1ZGC_24_layer589_303: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:02] 2BE2_23_layer297_181: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:02] 2BE2_24_layer255_126: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:10] 2F80_23_layer705_407: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:20] 2F81_23_layer837_515: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:20] 2F81_24_layer237_132: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:31] 2IDW_23_layer1044_612: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:41] 2IEN_23_layer934_541: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:41] 2IEN_23_layer1201_651: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:51] 2IEO_23_layer823_490: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:09:51] 2IEO_23_layer1044_617: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:01] 2ITP_23_layer281_161: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:01] 2ITP_23_layer494_277: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:12] 2ITT_23_layer1167_629: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:13] 2ITT_24_layer402_225: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:13] 2ITT_24_layer1095_556: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:24] 2ITY_23_layer925_531: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:34] 2IZL_23_layer270_153: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:50] 2RGP_23_layer108_56: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:50] 2RGP_23_layer451_198: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:10:50] 2RGP_24_layer420_201: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:06] 2ZD1_23_layer301_165: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:06] 2ZD1_23_layer513_251: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:07] 2ZD1_24_layer146_69: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:16] 2ZM3_23_layer916_566: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:16] 2ZM3_24_layer524_289: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:16] 2ZM3_24_layer1067_531: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:17] 2ZM3_24_layer1163_571: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:26] 3BEL_23_layer172_77: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:26] 3BEL_24_layer559_259: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:33] 3BGR_23_layer742_359: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:33] 3BGR_23_layer986_443: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:33] 3BGR_24_layer1057_492: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:40] 3DLE_23_layer159_87: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:41] 3DLE_24_layer1002_413: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:47] 3DLG_23_layer310_125: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:47] 3DLG_23_layer581_215: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:48] 3DLG_24_layer156_85: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:48] 3DLG_24_layer272_143: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:48] 3DLG_24_layer317_159: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:55] 3DOL_23_layer293_187: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:55] 3DOL_23_layer727_385: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:11:55] 3DOL_24_layer508_235: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:03] 3NW5_23_layer667_377: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:03] 3NW5_23_layer1028_568: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:03] 3NW5_24_layer347_172: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:11] 3NW6_23_layer1069_461: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:19] 3NW7_24_layer283_135: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:26] 4COX_23_layer499_236: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# RDKit WARNING: [12:12:26] 4COX_23_layer592_267: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.

# %%
#This is a sanity check step - to make sure everything worked above.
for mol in molecule_list:
    if mol is None: continue
    print(mol.GetNumAtoms())
# Out:
# 59
# 62
# 47
# 61
# 49
# 54
# 48
# 49
# 55
# 50
# 46
# 51
# 62
# 51
# 45
# 52
# 53
# 51
# 47
# 58
# 40
# 56
# 50
# 45
# 50
# 45
# 45
# 43
# 52
# 49
# 51
# 44
# 43
# 60
# 48
# 45
# 48
# 32
# 60
# 43
# 43
# 53
# 54
# 50
# 42
# 60
# 55
# 55
# 40
# 38
# 36
# 33
# 47
# 45
# 41
# 39
# 36
# 42
# 51
# 38
# 36
# 38
# 56
# 40
# 38
# 57
# 52
# 51
# 45
# 48
# 33
# 43
# 52
# 71
# 74
# 68
# 65
# 70
# 76
# 78
# 74
# 74
# 76
# 65
# 75
# 71
# 75
# 65
# 63
# 68
# 68
# 61
# 65
# 81
# 87
# 83
# 86
# 90
# 83
# 84

# %%
for mol in molecule_list:
    mol.UpdatePropertyCache(strict=False)
    RDFile.MolToPDBFile(mol,"out1.pdb")
    Chem.SanitizeMol(mol,sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL^Chem.SanitizeFlags.SANITIZE_KEKULIZE^Chem.SanitizeFlags.SANITIZE_SETAROMATICITY)
    RDFile.MolToPDBFile(mol,"out2.pdb")

# %% [markdown]
# ## Aromatic Rings

# %%
aromatic_count_list=[]
for mol in molecule_list:
    aromatic_count_list.append(Desc.NumAromaticRings(mol))

# %%
fig=plt.figure(num=None, figsize=(8, 2), dpi=400, facecolor='w', edgecolor='k',)
plt.title("NumAromaticRings")
plt.hist(aromatic_count_list,density=True,bins=[0,1,2,3,4,5,6])

# %%
with open("aromatic_ring_list.dat","w") as f:
    for i in aromatic_count_list:
        f.write("%s\n" % (i))
aromatic_count_list.clear()

# %% [markdown]
# ## LogP

# %%
logp_list=[]
for mol in molecule_list:
    logp_list.append(Chem.Crippen.MolLogP(mol))

# %%
fig=plt.figure(num=None, figsize=(8, 2), dpi=400, facecolor='w', edgecolor='k',)
plt.title("LogP")
plt.hist(logp_list,bins=50,density=True)

# %%
with open("logp.dat","w") as f:
    for i in logp_list:

        f.write("%s\n" % (i))
logp_list.clear()

# %% [markdown]
# ## Molecular Weight

# %%
mw_list=[]
for mol in molecule_list:
    mw_list.append(Desc.ExactMolWt(mol))

# %%
with open("mw_list.dat","w") as f:
    for i in mw_list:

        f.write("%s\n" % (i))

# %%
fig=plt.figure(num=None, figsize=(8, 2), dpi=400, facecolor='w', edgecolor='k',)
plt.title("MolecularWeight")
plt.hist(mw_list,bins=50,density=True)

# %% [markdown]
# # IDK

# %%
numhacceptors

# %%
numhdonors

# %%
#Hacc
bad_acc_counter=0
mol_counter=0
num_h_acc_list=[]
for mol in molecule_list:
    mol_counter+=1
    try:
        mol.UpdatePropertyCache(strict=False)
        num_h_acc_list.append(Desc.NumHAcceptors(mol))
        
    except:
        bad_acc_counter+=1
        
        continue

with open("numhacc_list.dat","w") as f:
    for i in num_h_acc_list:

        f.write("%s\n" % (i))
num_h_acc_list.clear() 
        
#Hdon
num_h_don_list=[]
bad_don_counter=0
mol_counter=0
for mol in molecule_list:
    mol_counter+=1
    try:
        mol.UpdatePropertyCache(strict=False)
        num_h_don_list.append(Desc.NumHDonors(mol))
        #print(Desc.NumHDonors(mol))
        
    except:
        bad_don_counter+=1
        
        continue

with open("numhdon_list.dat","w") as f:
    for i in num_h_don_list:

        f.write("%s\n" % (i))
num_h_acc_list.clear()
print("Bad acc: %d" % (bad_acc_counter))
print("Bad don: %d" % (bad_don_counter))

# %%
_fscores = None


def readFragmentScores(name='fpscores'):
    import gzip
    global _fscores
    # generate the full path filename:
    if name == "fpscores":
        print(os.getcwd())
        name = op.join(os.getcwd(), name)
    data = pickle.load(gzip.open('%s.pkl.gz' % name))
    outDict = {}
    for i in data:
        for j in range(1, len(i)):
            outDict[i[j]] = float(i[0])
    _fscores = outDict


def numBridgeheadsAndSpiro(mol, ri=None):
    nSpiro = rdMolDescriptors.CalcNumSpiroAtoms(mol)
    nBridgehead = rdMolDescriptors.CalcNumBridgeheadAtoms(mol)
    return nBridgehead, nSpiro


def calculateScore(m):
    if _fscores is None:
        readFragmentScores()
    m.UpdatePropertyCache(strict=False)
    # fragment score
    fp = rdMolDescriptors.GetMorganFingerprint(m,
                                               2)  # <- 2 is the *radius* of the circular fingerprint
    fps = fp.GetNonzeroElements()
    score1 = 0.
    nf = 0
    for bitId, v in fps.items():
        nf += v
        sfp = bitId
        score1 += _fscores.get(sfp, -4) * v
    score1 /= nf

    # features score
    nAtoms = m.GetNumAtoms()
    nChiralCenters = len(Chem.FindMolChiralCenters(m, includeUnassigned=True))
    ri = m.GetRingInfo()
    nBridgeheads, nSpiro = numBridgeheadsAndSpiro(m, ri)
    nMacrocycles = 0
    for x in ri.AtomRings():
        if len(x) > 8:
            nMacrocycles += 1

    sizePenalty = nAtoms**1.005 - nAtoms
    stereoPenalty = math.log10(nChiralCenters + 1)
    spiroPenalty = math.log10(nSpiro + 1)
    bridgePenalty = math.log10(nBridgeheads + 1)
    macrocyclePenalty = 0.
    # ---------------------------------------
    # This differs from the paper, which defines:
    #  macrocyclePenalty = math.log10(nMacrocycles+1)
    # This form generates better results when 2 or more macrocycles are present
    if nMacrocycles > 0:
        macrocyclePenalty = math.log10(2)

    score2 = 0. - sizePenalty - stereoPenalty - spiroPenalty - bridgePenalty - macrocyclePenalty

    # correction for the fingerprint density
    # not in the original publication, added in version 1.1
    # to make highly symmetrical molecules easier to synthetise
    score3 = 0.
    if nAtoms > len(fps):
        score3 = math.log(float(nAtoms) / len(fps)) * .5

    sascore = score1 + score2 + score3

    # need to transform "raw" value into scale between 1 and 10
    min = -4.0
    max = 2.5
    sascore = 11. - (sascore - min + 1) / (max - min) * 9.
    # smooth the 10-end
    if sascore > 8.:
        sascore = 8. + math.log(sascore + 1. - 9.)
    if sascore > 10.:
        sascore = 10.0
    elif sascore < 1.:
        sascore = 1.0
    return sascore

# %%
sasa_list=[]

for m in molecule_list:
    sasa_list.append(calculateScore(m))
    
with open("num_list.dat","w") as f:
    for i in sasa_list:
        f.write("%s\n" % (i))
        
sasa_list.clear()
# Out:
# /Users/Garn0123/Desktop/Grad_School/rizzo_research/dn_fraglib_comparison/2020.01.10_rdkit_mol_props
